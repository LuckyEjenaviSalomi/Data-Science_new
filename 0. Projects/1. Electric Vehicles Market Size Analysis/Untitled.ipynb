# %%
import os

# %%
os.getcwdb()
# Out:
# b'C:\\Users\\20454\\OneDrive - Nigerian National Petroleum Company Limited\\Documents\\GitHub\\Data-Science_new\\0. Projects\\1. Electric Vehicles Market Size Analysis'

# %%
os.chdir(r"C:\Users\20454\OneDrive - Nigerian National Petroleum Company Limited\INTERNAL AUDIT\AMS-TeamMate+\Data Migration\2023 OUTSOURCED JV & PSC AUDIT - FINAL SUBMISSION\FINAL AUDIT REPORTS")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\20454\\OneDrive - Nigerian National Petroleum Company Limited\\INTERNAL AUDIT\\AMS-TeamMate+\\Data Migration\\2023 OUTSOURCED JV & PSC AUDIT - FINAL SUBMISSION\\FINAL AUDIT REPORTS'
