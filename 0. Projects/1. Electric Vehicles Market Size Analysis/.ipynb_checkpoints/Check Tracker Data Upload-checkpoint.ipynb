# %% [markdown]
# ## File Path

# %%
filepath = r"C:\Users\20454\Downloads\Trackers_upload_test.xlsx"

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Read Data

# %%
data = pd.read_excel(filepath, sheet_name='Issues & Recommendations')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 data = pd.read_excel(filepath)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
# ...

# %% [markdown]
# ## Rename Header

# %%
first_row = np.array(data.head(1).values).flatten()
headers = data.columns

# %%
data_dict = {"header1": list(headers), "header2": list(first_row)}

# %%
df_headers = pd.DataFrame(data_dict)

# %%
df_headers.dropna(inplace=True)

# %%
rename_cols = dict(zip(df_headers['header1'], df_headers['header2']))

# %%
data.rename(columns=rename_cols, inplace=True)

# %% [markdown]
# ## Drop First Row

# %%
data = data.drop(index=0, axis=0)

# %% [markdown]
# ## Replace zeros with null

# %%
data.replace(0, pd.NA, inplace=True)

# %% [markdown]
# ## Check rows with blanks

# %%
empty_cols = list(data.columns[data.isnull().any()])

# %% [markdown]
# ## Required Cols

# %%
required_cols = ['Risk Assessment\nTaxonomy row', 'Project', 'Entity', 'Finding Title', 'Rating', 'Finding', 'Recurred', 'IssueManager', 'IssueReviewer', 'Released', 'IssueWorkflowState', 'Due Date', 'Review Due Date', 'Actual Created Date', 'Recommendation Title', 'Recommendation', 'Management Response', 'RecommendationWorkflowState', 'Response Due Date', 'Due Date', 'Review Due Date', 'Revised Due Date', 'Actual Created Date', 'RecommendationBusinessContact', 'RecommendationBusinessObserver', 'RecommendationBusinessReviewer']

# %% [markdown]
# ## Final: Check Empty Required Columns

# %%
cols = [col for col in required_cols if col in empty_cols]
msg = 'There are not empty required columns.'
if len(cols):
    msg = f'There are {len(cols)} empty required columns: {cols}'

print(msg)
